# %% [markdown]
# # Einlesen des Datensatzes

# %%
import pandas as pd
import numpy as np
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../Datensatz/df_original.csv")
df
# Out:
#    Unnamed: 0         Autor                                       Titel  \
# 0           0  J.K. Rowling  HARRY POTTER und der Gefangene von Askaban
# 1           1  J.K. Rowling          HARRY POTTER und der Halbblutprinz
# 2           2  J.K. Rowling       HARRY POTTER und der Orden des Phönix
# 3           3  J.K. Rowling       HARRY POTTER und der Stein der Weisen
# 4           4  J.K. Rowling  HARRY POTTER und die Heiligtümer des Todes
# 5           5  J.K. Rowling  HARRY POTTER und die Kammer des Schreckens
# 6           6  J.K. Rowling             HARRY POTTER und der Feuerkelch
#
#     Übersetzer                             Original_Titel               ISBN  \
# 0  Klaus Fritz   Harry Potter and the Prisoner of Azkaban  978-1-78110-057-8
# 1  Klaus Fritz     Harry Potter and the Half-Blood Prince  978-1-78110-060-8
# 2  Klaus Fritz  Harry Potter and the Order of the Phoenix  978-1-78110-059-2
# 3  Klaus Fritz   Harry Potter and the Philosopher’s Stone  978-1-78110-055-4
# ...

# %% [markdown]
# # Verteilung der Buchlängen

# %%
books = np.unique(df.Titel)
print(len(np.unique(df.Titel)))
# Out:
# 7

# %%
mean ={}
for a in books:
    mean[a] = int(np.mean(df.number_of_tokens[df.Titel==a]))

# %%
ax = sns.distplot(list(mean.values()), rug=True, kde=False)
ax.set_xlabel("book length")
ax.set_ylabel("occurence")
ax.set_title("Distribution of Booklength")
#plt.savefig("../../")
plt.show()

# %% [markdown]
# # Wordclouds

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

cv = CountVectorizer(max_features=2000, min_df=1, max_df=3000)
cv.fit(df['clean_text'])

results = cv.transform(df['clean_text'])

features = cv.get_feature_names()

# %%
df_res = pd.DataFrame(results.toarray(), columns=features)
df_res = df_res.set_index(df.Titel)

# %%
df_res.loc['sum']=df_res.sum()
df_res = df_res.div(df_res.sum(axis=1), axis=0)

# %%
df_res.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
df_res
# Out:
#                                                harry     sagte       ron  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.039558  0.027872  0.015040
# HARRY POTTER und der Halbblutprinz          0.036898  0.028326  0.011209
# HARRY POTTER und der Orden des Phönix       0.034930  0.029632  0.011118
# HARRY POTTER und der Stein der Weisen       0.037951  0.021237  0.012073
# HARRY POTTER und die Heiligtümer des Todes  0.036305  0.022367  0.013352
# HARRY POTTER und die Kammer des Schreckens  0.041783  0.028550  0.017715
# HARRY POTTER und der Feuerkelch             0.036622  0.026455  0.012020
# sum                                         0.037033  0.026708  0.012695
#
#                                              hermine       ich  dumbledore  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.013311  0.007874    0.003291
# HARRY POTTER und der Halbblutprinz          0.009025  0.010110    0.012693
# ...

# %% [markdown]
# ## Wordcloud für HP1

# %%
book1 = df_res[df_res.index=="HARRY POTTER und der Stein der Weisen"]
book1.loc['sum']=book1.sum()
book1 = book1.div(book1.sum(axis=1), axis=0)
book1.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                           harry     sagte       ron    hagrid  \
# Titel
# HARRY POTTER und der Stein der Weisen  0.037951  0.021237  0.012073  0.009958
# sum                                    0.037951  0.021237  0.012073  0.009958
#
#                                         hermine       ich    schon   konnte  \
# Titel
# HARRY POTTER und der Stein der Weisen  0.007902  0.007872  0.00655  0.00564
# sum                                    0.007902  0.007872  0.00655  0.00564
#
#                                           nicht  professor  ...  yaxley  \
# Titel                                                       ...
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book1.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP1.png")

# %% [markdown]
# ## Wordcloud für HP2

# %%
book2 = df_res[df_res.index=="HARRY POTTER und die Kammer des Schreckens"]
book2.loc['sum']=book2.sum()
book2 = book2.div(book2.sum(axis=1), axis=0)
book2.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                                harry    sagte       ron  \
# Titel
# HARRY POTTER und die Kammer des Schreckens  0.041783  0.02855  0.017715
# sum                                         0.041783  0.02855  0.017715
#
#                                              hermine       ich       sah  \
# Titel
# HARRY POTTER und die Kammer des Schreckens  0.007803  0.007618  0.005931
# sum                                         0.007803  0.007618  0.005931
#
#                                             lockhart   malfoy  professor  \
# Titel
# HARRY POTTER und die Kammer des Schreckens   0.00551  0.00543   0.005141
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book2.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP2.png")

# %% [markdown]
# ## Wordcloud für HP3

# %%
book3 = df_res[df_res.index=="HARRY POTTER und der Gefangene von Askaban"]
book3.loc['sum']=book3.sum()
book3 = book3.div(book3.sum(axis=1), axis=0)
book3.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                                harry     sagte      ron  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.039558  0.027872  0.01504
# sum                                         0.039558  0.027872  0.01504
#
#                                              hermine  professor       ich  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.013311   0.008582  0.007874
# sum                                         0.013311   0.008582  0.007874
#
#                                                lupin     black      sah  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.007749  0.006583  0.00577
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book3.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP3.png")

# %% [markdown]
# ## Wordcloud für HP4

# %%
book = df_res[df_res.index=="HARRY POTTER und der Feuerkelch"]
book.loc['sum']=book.sum()
book = book.div(book.sum(axis=1), axis=0)
book.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                     harry     sagte      ron  hermine  \
# Titel
# HARRY POTTER und der Feuerkelch  0.036622  0.026455  0.01202  0.01007
# sum                              0.036622  0.026455  0.01202  0.01007
#
#                                       ich       sah  dumbledore        mr  \
# Titel
# HARRY POTTER und der Feuerkelch  0.006998  0.006778    0.006778  0.006498
# sum                              0.006998  0.006778    0.006778  0.006498
#
#                                     hatte     schon  ...  porträts  mclaggen  \
# Titel                                                ...
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP4.png")

# %% [markdown]
# ## Wordcloud für HP5

# %%
book5 = df_res[df_res.index=="HARRY POTTER und der Orden des Phönix"]
book5.loc['sum']=book5.sum()
book5 = book5.div(book5.sum(axis=1), axis=0)
book5.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                          harry     sagte   hermine       ron  \
# Titel
# HARRY POTTER und der Orden des Phönix  0.03493  0.029632  0.011457  0.011118
# sum                                    0.03493  0.029632  0.011457  0.011118
#
#                                             ich        ja    hatte      war  \
# Titel
# HARRY POTTER und der Orden des Phönix  0.007919  0.006691  0.00626  0.00615
# sum                                    0.007919  0.006691  0.00626  0.00615
#
#                                          sirius  dumbledore  ...  horkrux  \
# Titel                                                        ...
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book5.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP5.png")

# %% [markdown]
# ## Wordcloud für HP6

# %%
book6 = df_res[df_res.index=="HARRY POTTER und der Halbblutprinz"]
book6.loc['sum']=book6.sum()
book6 = book6.div(book6.sum(axis=1), axis=0)
book6.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book6
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                        harry     sagte  dumbledore       ron  \
# Titel
# HARRY POTTER und der Halbblutprinz  0.036898  0.028326    0.012693  0.011209
# sum                                 0.036898  0.028326    0.012693  0.011209
#
#                                         ich   hermine       war     hatte  \
# Titel
# HARRY POTTER und der Halbblutprinz  0.01011  0.009025  0.007528  0.007212
# sum                                 0.01011  0.009025  0.007528  0.007212
#
#                                        nicht        ja  ...  ratte  angelina  \
# Titel                                                   ...
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book6.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP6.png")

# %% [markdown]
# ## Wordcloud für HP7

# %%
book7 = df_res[df_res.index=="HARRY POTTER und die Heiligtümer des Todes"]
book7.loc['sum']=book7.sum()
book7 = book7.div(book7.sum(axis=1), axis=0)
book7.sort_values(by=['sum'], axis=1, inplace=True, ascending=False)
book7
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                                harry     sagte   hermine  \
# Titel
# HARRY POTTER und die Heiligtümer des Todes  0.036305  0.022367  0.013987
# sum                                         0.036305  0.022367  0.013987
#
#                                                  ron       war       ich  \
# Titel
# HARRY POTTER und die Heiligtümer des Todes  0.013352  0.009284  0.008258
# sum                                         0.013352  0.009284  0.008258
#
#                                                hatte  zauberstab  dumbledore  \
# Titel
# HARRY POTTER und die Heiligtümer des Todes  0.007623    0.006145     0.00601
# ...

# %%
from wordcloud import WordCloud

def makeImage(text, figname):
    wc = WordCloud(background_color="white", max_words=1000)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig(figname)
    plt.show()

text = book7.loc['sum']
makeImage(text, "../../Bilder/WordClouds_HP7.png")

# %% [markdown]
# # Worthäufigkeitsverteilung nach Büchern

# %%
mfw = df_res.copy()
mfw = mfw.iloc[:,:31]
mfw.dropna()
mfw
# Out:
#                                                harry     sagte       ron  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.039558  0.027872  0.015040
# HARRY POTTER und der Halbblutprinz          0.036898  0.028326  0.011209
# HARRY POTTER und der Orden des Phönix       0.034930  0.029632  0.011118
# HARRY POTTER und der Stein der Weisen       0.037951  0.021237  0.012073
# HARRY POTTER und die Heiligtümer des Todes  0.036305  0.022367  0.013352
# HARRY POTTER und die Kammer des Schreckens  0.041783  0.028550  0.017715
# HARRY POTTER und der Feuerkelch             0.036622  0.026455  0.012020
# sum                                         0.037033  0.026708  0.012695
#
#                                              hermine       ich  dumbledore  \
# Titel
# HARRY POTTER und der Gefangene von Askaban  0.013311  0.007874    0.003291
# HARRY POTTER und der Halbblutprinz          0.009025  0.010110    0.012693
# ...

# %%
HP1 = mfw[mfw.index=="HARRY POTTER und der Stein der Weisen"]
HP1.loc['sum']=HP1.sum()
HP1 = HP1.div(HP1.sum(axis=1), axis=0)

# %%
HP2 = mfw[mfw.index=="HARRY POTTER und die Kammer des Schreckens"]
HP2.loc['sum']=HP2.sum()
HP2 = HP2.div(HP2.sum(axis=1), axis=0)

# %%
HP3 = mfw[mfw.index=="HARRY POTTER und der Gefangene von Askaban"]
HP3.loc['sum']=HP3.sum()
HP3 = HP3.div(HP3.sum(axis=1), axis=0)

# %%
HP4 = mfw[mfw.index=="HARRY POTTER und der Feuerkelch"]
HP4.loc['sum']=HP4.sum()
HP4 = HP4.div(HP4.sum(axis=1), axis=0)

# %%
HP5 = mfw[mfw.index=="HARRY POTTER und der Orden des Phönix"]
HP5.loc['sum']=HP5.sum()
HP5 = HP5.div(HP5.sum(axis=1), axis=0)

# %%
HP6 = mfw[mfw.index=="HARRY POTTER und der Halbblutprinz"]
HP6.loc['sum']=HP6.sum()
HP6 = HP6.div(HP6.sum(axis=1), axis=0)

# %%
HP7 = mfw[mfw.index=="HARRY POTTER und die Heiligtümer des Todes"]
HP7.loc['sum']=HP7.sum()
HP7 = HP7.div(HP7.sum(axis=1), axis=0)

# %%
ax = sns.distplot(HP1.loc['sum'], hist=False, label="Harry Potter und der Stein der Weisen")
ax = sns.distplot(HP2.loc['sum'], hist=False, label="Harry Potter und die Kammer des Schreckens")
ax = sns.distplot(HP3.loc['sum'], hist=False, label="Harry Potter und der Gefangene von Askaban")
ax = sns.distplot(HP4.loc['sum'], hist=False, label="Harry Potter und der Feuerkelch")
ax = sns.distplot(HP5.loc['sum'], hist=False, label="Harry Potter und der Orden des Phoenix")
ax = sns.distplot(HP6.loc['sum'], hist=False, label="Harry Potter und der Halbblutprinz")
ax = sns.distplot(HP7.loc['sum'], hist=False, label="Harry Potter und die Heiligtümer des Todes")
ax.set_xlabel("wordfrequency")
ax.set_ylabel("occurence")
plt.title("Distribution of Wordfrequencies")
#plt.savefig("")
plt.legend()

# %%
HP1 = mfw[mfw.index=="HARRY POTTER und der Stein der Weisen"]
HP1.loc['sum']=HP1.sum()
HP1 = HP1.div(HP1.sum(axis=1), axis=0)

# %%
HP2 = mfw[mfw.index=="HARRY POTTER und die Kammer des Schreckens"]
HP2.loc['sum']=HP2.sum()
HP2 = HP2.div(HP2.sum(axis=1), axis=0)

# %%
HP3 = mfw[mfw.index=="HARRY POTTER und der Gefangene von Askaban"]
HP3.loc['sum']=HP3.sum()
HP3 = HP3.div(HP3.sum(axis=1), axis=0)

# %%
HP4 = mfw[mfw.index=="HARRY POTTER und der Feuerkelch"]
HP4.loc['sum']=HP4.sum()
HP4 = HP4.div(HP4.sum(axis=1), axis=0)

# %%
HP5 = mfw[mfw.index=="HARRY POTTER und der Orden des Phoenix"]
HP5.loc['sum']=HP5.sum()
HP5 = HP5.div(HP5.sum(axis=1), axis=0)

# %%
HP6 = mfw[mfw.index=="HARRY POTTER und der Halbblutprinz"]
HP6.loc['sum']=HP6.sum()
HP6 = HP6.div(HP6.sum(axis=1), axis=0)

# %%
import matplotlib.patches as mpatches
green = mpatches.Patch(color='g', label='Harry Potter und der Stein der Weisen')
red = mpatches.Patch(color='r', label='Harry Potter und die Kammer des Schreckens')
yellow = mpatches.Patch(color='y', label='Harry Potter und der Gefangene von Askaban')
purple = mpatches.Patch(color='c', label='Harry Potter und der Feuerkelch')
blue = mpatches.Patch(color='b', label='Harry Potter und der Orden des Phoenix')
magenta = mpatches.Patch(color='m', label='Harry Potter und der Halbblutprinz')
black = mpatches.Patch(color='k', label='Harry Potter und die Heiligtümer des todes')


fig, ax = plt.subplots(figsize=(25,10))
ax = sns.pointplot(x=HP1.columns, y=HP1.loc['sum'],color='g')
ax = sns.pointplot(x=HP2.columns, y=HP2.loc['sum'], color='r')
ax = sns.pointplot(x=HP3.columns, y=HP3.loc['sum'], color='y')
ax = sns.pointplot(x=HP4.columns, y=HP4.loc['sum'], color='c')
ax = sns.pointplot(x=HP5.columns, y=HP5.loc['sum'], color='b')
ax = sns.pointplot(x=HP6.columns, y=HP6.loc['sum'], color='m')
ax = sns.pointplot(x=HP7.columns, y=HP7.loc['sum'], color='k')
plt.title("Frequencies of 50 MFW")
plt.legend(handles=[green, red, blue, yellow, purple, magenta, black])
plt.savefig("../../Bilder/frequencies_of_50_MFW.png")

# %% [markdown]
# # Länge der Bücher

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

x = ['Harry Potter und der Stein der Weisen', 'Harry Potter und die Kammer des Schreckens', 
     'Harry Potter und der Gefangene von Askaban', 'Harry Potter und der Feuerkelch', 
     'Harry Potter und der Orden des Phoenix', 'Harry Potter und der Halbblutprinz',
    'Harry Potter und die Heiligtümer des todes']
energy = [84152.0, 91968.0, 115980.0, 203341.0, 268898.0, 179884.0, 207576.0]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green')
plt.xlabel("Books")
plt.ylabel("Number of Tokens")
plt.title("Books length")

plt.xticks(x_pos, x, rotation='vertical')

plt.show()
