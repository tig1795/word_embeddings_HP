# %%
import pandas as pd

# %%
df = pd.read_csv('../../../../Desktop/df_fanfiction.csv')

# %%
hp_sample = df.copy()
hp_sample = hp_sample.sample(frac=.025, replace=False, random_state=42)
hp_sample
# Out:
#         Unnamed: 0           Autor  \
# 3114  k00500041544     Ivy-and-Liz
# 4978  k00500050690         Slummmy
# 1569  k00500034109       Perscitia
# 764   k00500029876  double-o-seven
# 7296  k00500062657     redangeleve
# ...            ...             ...
# 6058  k00500056505      suppenhuhn
# 5829  k00500055281   Fantasie Book
# 3527  k00500043710      R3AP3R2501
# 1631  k00500034431       Spaghetti
# 5903  k00500055620    BLACK BAMBIE
#
#                                                 Titel  Datum  \
# 3114                         Ein Job wie jeder andere   2007
# 4978                   Ich haette dich retten koennen   2017
# 1569                            Daily Propheting 2017   2017
# 764     Adventskalender der kuriosen Pairings Level 2   2017
# 7296                                     Shape of you   2017
# ...                                               ...    ...
# 6058                                             Miau   2010
# ...

# %%
hp_sample.to_csv("../../Datensatz/df_fanfiction_2_5.csv")
