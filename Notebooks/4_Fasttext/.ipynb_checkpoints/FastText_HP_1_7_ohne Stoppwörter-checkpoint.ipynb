# %% [markdown]
# # Imports und Datenvorbereitung

# %%
import pandas as pd
import numpy as np
import re
import nltk
import os
from joblib import Parallel, delayed  
from nltk.corpus import stopwords
from gensim.models import FastText
from gensim.models.phrases import Phraser, Phrases
import codecs
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from tabulate import tabulate

nltk.download('punkt')
tokenizer = nltk.data.load('tokenizers/punkt/german.pickle')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Elke\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
hp = pd.read_csv('data/df_original.csv', encoding='utf-8')
hp.head()
# Out:
#    Unnamed: 0         Autor                                       Titel  \
# 0           0  J.K. Rowling  HARRY POTTER und der Gefangene von Askaban
# 1           1  J.K. Rowling          HARRY POTTER und der Halbblutprinz
# 2           2  J.K. Rowling       HARRY POTTER und der Orden des Phönix
# 3           3  J.K. Rowling       HARRY POTTER und der Stein der Weisen
# 4           4  J.K. Rowling  HARRY POTTER und die Heiligtümer des Todes
#
#     Übersetzer                             Original_Titel               ISBN  \
# 0  Klaus Fritz   Harry Potter and the Prisoner of Azkaban  978-1-78110-057-8
# 1  Klaus Fritz     Harry Potter and the Half-Blood Prince  978-1-78110-060-8
# 2  Klaus Fritz  Harry Potter and the Order of the Phoenix  978-1-78110-059-2
# 3  Klaus Fritz   Harry Potter and the Philosopher’s Stone  978-1-78110-055-4
# 4  Klaus Fritz       Harry Potter and the Deathly Hallows  978-1-78110-061-5
#
#    Datum                                               Text  \
# ...

# %%
stopwords = stopwords.words('german')

# %%
# Hilfsfunktion zur Bereinigung und Tokenisierung

def sentence_to_wordlist(raw:str):
    
    text = re.sub('[^A-Za-z_äÄöÖüÜß]',' ', raw).split()
    filtered_text = [word for word in text if word not in stopwords]
    return filtered_text

# %%
# Hilfsfunktion zur Extraktion der Sätze
# gibt eine List von tokenisierten Sätzen aus 
# berücksichtigt auch Bigramme

def prepare_text(raw_text):
    raw_sentences = tokenizer.tokenize(str(raw_text).lower())
    tokenized_sentences = Parallel(n_jobs=-1)(delayed(sentence_to_wordlist)(raw_sentence) for raw_sentence in raw_sentences)
    phrases = Phrases(tokenized_sentences)
    bigram = Phraser(phrases)
    sentences = list(bigram[tokenized_sentences])
    return sentences

# %%
text = ''

for i in hp['Text']:
    text = text + i

# %%
sentences = prepare_text(text)

# sentences ist eine Liste von tokenisierten Sätzen, zum Beispiel:
print(sentences[1000])
# Out:
# ['kamen', 'wachen_askaban', 'redeten']

# %% [markdown]
# # Training von FastText (mit Gensim)

# %%
# Paramter setzen
workers = 4
seed = 42 #just because

# %%
# %%time 

# Training

ft_hp = FastText(sentences=sentences, 
                 size=300, 
                 window=7, 
                 min_count=15, 
                 workers=workers, 
                 min_alpha=0.0001,
                 sg=1, 
                 seed=seed)

# trainiertes Modell speichern
# ft_hp.save(os.path.join('trained_models', 'hp1_7_ft.bin'))
# Out:
# Wall time: 4min 34s

# %%
# trainiertes Modell laden
ft_hp = FastText.load(os.path.join('trained_models', 'hp1_7_ft.bin'))

# %% [markdown]
# # Exploration des FastText-Modells

# %% [markdown]
# ## Wörter als Vektoren

# %%
# Vergleicht 2 Vektoren (Cosinus Similarität)

ft_hp.wv.similarity('harry', 'ron')
# Out:
# 0.5356212

# %%
ft_hp.wv.similarity('harry', 'besen')
# Out:
# 0.4473854

# %%
# %%time

# Wortvektoren als DataFrame (Reduktion auf 2 Dimensionen mit TSNE)

tsne = TSNE(n_components=2, random_state=seed)
word_vectors = ft_hp.wv.syn0
word_vectors_2d = tsne.fit_transform(word_vectors)

points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, word_vectors_2d[ft_hp.wv.vocab[word].index])
            for word in ft_hp.wv.vocab
        ]
    ],
    columns=['word', 'x', 'y'])

# random 5 Wörter und ihre Koordinaten ausgeben
points.sample(5)
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   after removing the cwd from sys.path.
# Wall time: 1min 10s
#                word          x          y
# 2485        auswahl -29.910883   5.283463
# 2486     hufflepuff -20.228586  28.286737
# 363            bald -19.445309  16.740892
# 3517   gefährlichen -14.926116  37.716545
# 4865  schlammblüter -21.084454 -16.142143

# %%
# alle Wortvektoren plotten

sns.set_context('poster')

plt.style.use('seaborn-whitegrid')
points.plot.scatter('x', 'y', s=10, figsize=(20, 12))

# %%
# Hilfsfunktion, um durch den Plot zu navigieren (ranzoomen)

def plot_region(x_bounds, y_bounds, padding=0.005, fontsize=11):
    myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]
    
    ax = myslice.plot.scatter('x', 'y', s=35, figsize=(9, 5))
    for i, point in myslice.iterrows():
        ax.text(point.x + padding, point.y + padding, point.word, fontsize=fontsize)

# %%
# ranzoomen
x_bounds = (-20, 0)       # Bereich x-Achse einstellen
y_bounds = (-80, -60)     # Bereich y-Achse einstellen

myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]

len(myslice)

plot_region(x_bounds=x_bounds, y_bounds=y_bounds)

# %%
# nur ausgewählte Wortvektoren plotten

tsne = TSNE(n_components=2, random_state=seed)

words =  ['harry', 'ron', 'hermine', 'dean', 'neville', 'luna', 
          'ginny', 'fred', 'george','mr_weasley', 'mrs_weasley',
          'krumm', 'fleur', 'cedric', 
          'malfoy', 'crabbe', 'goyle', 'voldemort', 'bellatrix', 'wurmschwanz', 
          'hagrid', 'dumbledore', 'snape', 'sirius',
          'hogwarts', 'gryffindor', 'slytherin', 'ravenclaw', 'hufflepuff',
          'hosmeade', 'winkelgasse', 'little_whinging', 'london', 'gringotts', 'ministerium', 'azkaban', 'fuchsbau',
          'quidditch', 'besen', 'feuerblitz', 'schnatz', 'sucher', 'treiber', 'klatscher',
          'tier', 'animagus', 'drache', 'phönix', 'eule', 'katze', 'hund', 'hedwig', 'fang', 'geist', 'elf']

vectors = [ft_hp[word] for word in words]
plt.figure(figsize=[18,18])
plt.style.use('seaborn-whitegrid')
Y = tsne.fit_transform(vectors[:200])
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
plt.show()
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Ähnliche Wörer

# %%
ft_hp.wv.most_similar(positive=['hogwarts'], topn=10)
# Out:
# [('hogwarts_schule', 0.9834526777267456),
#  ('jahr_hogwarts', 0.975834846496582),
#  ('hogwarts_schüler', 0.95057213306427),
#  ('punkt', 0.9235498309135437),
#  ('hogwarts_express', 0.9170972108840942),
#  ('abteilung_magische', 0.9164541363716125),
#  ('schuljahr', 0.9150895476341248),
#  ('mitgeteilt', 0.9109485745429993),
#  ('zeitpunkt', 0.910651445388794),
#  ('außerhalb_schule', 0.9026442766189575)]

# %%
ft_hp.wv.most_similar(positive=['quidditch'], topn=10)
# Out:
# [('quidditch_spiel', 0.9852548837661743),
#  ('quidditch_mannschaft', 0.9831352829933167),
#  ('quidditch_spieler', 0.9812797904014587),
#  ('quidditch_feld', 0.9683177471160889),
#  ('quidditch_pokal', 0.9670454263687134),
#  ('quidditch_training', 0.9668123126029968),
#  ('mannschaft', 0.9602862596511841),
#  ('fünfzig', 0.9479210376739502),
#  ('spiel', 0.9363072514533997),
#  ('spieler', 0.9360341429710388)]

# %%
ft_hp.wv.most_similar(positive=['zauberer'], topn=10)
# Out:
# [('zauberern', 0.9841498732566833),
#  ('zauberers', 0.9837961792945862),
#  ('zauberei', 0.9648051857948303),
#  ('zaubern', 0.9535560607910156),
#  ('zauber', 0.9487018585205078),
#  ('zaubergamot', 0.9478418827056885),
#  ('zaubergamots', 0.9463927745819092),
#  ('hexe_zauberer', 0.943290650844574),
#  ('zaubererwelt', 0.9416311979293823),
#  ('hexen_zauberer', 0.9197887182235718)]

# %%
# Hilfsfunktion zum Plotten ähnlicher Wörter im Vektorraum

def plot_closest_words(model, word, plot_style):
    
    arr = np.empty((0,300), dtype='f') 
    closest_words = model.wv.similar_by_word(word)
    word_labels = [word]
    arr = np.append(arr, np.array([model[word]]), axis=0)
    
    for wrd_score in closest_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
                
    plt.figure(figsize=[12,6])
    plt.style.use(plot_style)
                    
    tsne = TSNE(n_components=2, random_state=42)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
    plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
    plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
plot_closest_words(ft_hp, 'harry', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
plot_closest_words(ft_hp, 'quidditch', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
plot_closest_words(ft_hp, 'schule', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## Verrechnung der Vektoren

# %%
# Hilfsfunktion zur Analogiebildung

def analogy(model, word1, word2, word3):
    similarities = model.wv.most_similar(positive=[word1, word3], negative=[word2])
    word4 = similarities[0][0]
    print('{word1} steht in Beziehung zu {word2}, wie {word4} zu {word3}'.format(**locals()))
    return word4

# %%
analogy(ft_hp, 'gryffindor', 'harry', 'luna')
# Out:
# gryffindor steht in Beziehung zu harry, wie gryffindors zu luna
# 'gryffindors'

# %%
analogy(ft_hp, 'hedwig', 'harry', 'hagrid')
# Out:
# hedwig steht in Beziehung zu harry, wie ei zu hagrid
# 'ei'

# %%
analogy(ft_hp, 'bibliothek', 'hermine', 'ron')
# Out:
# bibliothek steht in Beziehung zu hermine, wie frühstück zu ron
# 'frühstück'

# %%
analogy(ft_hp, 'lehrer', 'mann', 'frau')
# Out:
# lehrer steht in Beziehung zu mann, wie lehrerin zu frau
# 'lehrerin'
