# %% [markdown]
# # Imports und Datenvorbereitung

# %%
import pandas as pd
import numpy as np
import re
import nltk
import os
from joblib import Parallel, delayed  
from nltk.corpus import stopwords
from gensim.models import FastText
from gensim.models.phrases import Phraser, Phrases
import codecs
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from tabulate import tabulate

nltk.download('punkt')
tokenizer = nltk.data.load('tokenizers/punkt/german.pickle')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Elke\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
hp = pd.read_csv('data/df_fanfiction_2_5.csv', encoding='utf-8')
hp.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1           Autor  \
# 0        3114  k00500041544     Ivy-and-Liz
# 1        4978  k00500050690         Slummmy
# 2        1569  k00500034109       Perscitia
# 3         764  k00500029876  double-o-seven
# 4        7296  k00500062657     redangeleve
#
#                                            Titel  Datum  \
# 0                       Ein Job wie jeder andere   2007
# 1                 Ich haette dich retten koennen   2017
# 2                          Daily Propheting 2017   2017
# 3  Adventskalender der kuriosen Pairings Level 2   2017
# 4                                   Shape of you   2017
#
#                                                 Text
# 0    Disclaimer:Die wunderbaren Welten von Harry ...
# 1    Hier das Valentinswichteln für Valentia. Ich...
# 2    Hallo!Herzlich Willkommen zu dieser Sammlung...
# 3    WARNUNG: CHARACTER DEATHEr hatte doch alles ...
# 4    Hallo liebe Leser,lange gab es im Harry Pott...

# %%
stopwords = stopwords.words('german')

# %%
# Hilfsfunktion zur Bereinigung und Tokenisierung

def sentence_to_wordlist(raw:str):
    
    text = re.sub('[^A-Za-z_äÄöÖüÜß]',' ', raw).split()
    filtered_text = [word for word in text if word not in stopwords]
    return filtered_text

# %%
# Hilfsfunktion zur Extraktion der Sätze
# gibt eine List von tokenisierten Sätzen aus 
# berücksichtigt auch Bigramme

def prepare_text(raw_text):
    raw_sentences = tokenizer.tokenize(str(raw_text).lower())
    tokenized_sentences = Parallel(n_jobs=-1)(delayed(sentence_to_wordlist)(raw_sentence) for raw_sentence in raw_sentences)
    phrases = Phrases(tokenized_sentences)
    bigram = Phraser(phrases)
    sentences = list(bigram[tokenized_sentences])
    return sentences

# %%
text = ''

for i in hp['Text']:
    text = text + i

# %%
sentences = prepare_text(text)

# sentences ist eine Liste von tokenisierten Sätzen, zum Beispiel:
print(sentences[1000])
# Out:
# ['wer', 'schon', 'freiwillig', 'gute', 'haushaltskraft', 'gehen_lassen', 'ajka', 'überlegte', 'herren', 'könnten', 'bezahlung', 'engagieren']

# %% [markdown]
# # Training von FastText (mit Gensim)

# %%
# Paramter setzen
workers = 4
seed = 42 #just because

# %%
# %%time 

# Training

ft_ff = FastText(sentences=sentences, 
                 size=300, 
                 window=7, 
                 min_count=15, 
                 workers=workers, 
                 min_alpha=0.0001,
                 sg=1, 
                 seed=seed)

# trainiertes Modell speichern
# ft_ff.save(os.path.join('trained_models', 'hp_ff_ft.bin'))
# Out:
# Wall time: 6min 33s

# %%
# trainiertes Modell laden
ft_ff = FastText.load(os.path.join('trained_models', 'hp_ff_ft.bin'))

# %% [markdown]
# # Exploration des FastText-Modells

# %% [markdown]
# ## Wörter als Vektoren

# %%
# Vergleicht 2 Vektoren (Cosinus Similarität)

ft_ff.wv.similarity('harry', 'ron')
# Out:
# 0.47393593

# %%
ft_ff.wv.similarity('harry', 'besen')
# Out:
# 0.21409672

# %%
# %%time

# Wortvektoren als DataFrame (Reduktion auf 2 Dimensionen mit TSNE)

tsne = TSNE(n_components=2, random_state=seed)
word_vectors = ft_ff.wv.syn0
word_vectors_2d = tsne.fit_transform(word_vectors)

points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, word_vectors_2d[ft_ff.wv.vocab[word].index])
            for word in ft_ff.wv.vocab
        ]
    ],
    columns=['word', 'x', 'y'])

# random 5 Wörter und ihre Koordinaten ausgeben
points.sample(5)
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   after removing the cwd from sys.path.
# Wall time: 8min 1s
#                  word          x          y
# 14156  seltsamerweise  -1.342978   1.647370
# 14535     höflichkeit  -7.501256   0.968952
# 5772            kühle  34.938900  21.150358
# 1825            wovon -45.192123 -18.185808
# 11840        krächzen   0.144101  42.245522

# %%
# alle Wortvektoren plotten

sns.set_context('poster')

plt.style.use('seaborn-whitegrid') 
points.plot.scatter('x', 'y', s=10, figsize=(20, 12))

# %%
# Hilfsfunktion, um durch den Plot zu navigieren (ranzoomen)

def plot_region(x_bounds, y_bounds, padding=0.005, fontsize=11):
    myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]
    
    ax = myslice.plot.scatter('x', 'y', s=35, figsize=(9, 5))
    for i, point in myslice.iterrows():
        ax.text(point.x + padding, point.y + padding, point.word, fontsize=fontsize)

# %%
# ranzoomen
x_bounds = (60, 80)       # Bereich x-Achse einstellen
y_bounds = (50, 60)       # Bereich y-Achse einstellen

myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]

len(myslice)

plot_region(x_bounds=x_bounds, y_bounds=y_bounds)

# %%
# nur ausgewählte Wortvektoren plotten

tsne = TSNE(n_components=2, random_state=seed)

words =  ['harry', 'ron', 'hermine', 'dean', 'neville', 'luna', 
          'ginny', 'fred', 'george','mr_weasley', 'mrs_weasley', 'weasley', 'fuchsbau',
          'malfoy', 'crabbe', 'goyle', 'voldemort', 'dumbledore', 'snape',
          'hogwarts', 'hogwartsschule', 'schule', 'schuljahr', 'schulsprecher',
          'gryffindor', 'slytherin', 'ravenclaw', 'hufflepuff',
          'quidditch', 'quidditchspiel', 'quidditchtraining', 'feuerblitz', 'schnatz', 'sucher', 'treiber', 'klatscher', 
          'drache', 'phönix', 'eule', 'katze', 'hund', 'hedwig', 'geist', 'elf']

vectors = [ft_ff[word] for word in words]
plt.figure(figsize=[20,10])
plt.style.use('seaborn-whitegrid')
Y = tsne.fit_transform(vectors[:200])
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
plt.show()
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ## Ähnliche Wörer

# %%
ft_ff.wv.most_similar(positive=['hogwarts'], topn=10)
# Out:
# [('jahr_hogwarts', 0.9030718803405762),
#  ('hogwarts_schule', 0.8953695297241211),
#  ('hogwartsexpress', 0.8749233484268188),
#  ('gänge_hogwarts', 0.8745508193969727),
#  ('hogwarts_express', 0.8720049858093262),
#  ('hogwartsschüler', 0.8330725431442261),
#  ('schlacht_hogwarts', 0.8222526907920837),
#  ('hogwarts_zurückkehren', 0.805279016494751),
#  ('schulleiter_hogwarts', 0.8001293540000916),
#  ('hogwarts_verlassen', 0.7827106714248657)]

# %%
ft_ff.wv.most_similar(positive=['quidditch'], topn=10)
# Out:
# [('quidditchspiel', 0.95257967710495),
#  ('quidditch_spiel', 0.9400564432144165),
#  ('quidditsch', 0.9349809885025024),
#  ('quidditchfeld', 0.9322068691253662),
#  ('quidditch_spielen', 0.9015785455703735),
#  ('partie', 0.7655407190322876),
#  ('robyn_corvin', 0.731507420539856),
#  ('kaufte', 0.717156171798706),
#  ('jahrgangs', 0.7155190706253052),
#  ('honigtopf', 0.7063792943954468)]

# %%
ft_ff.wv.most_similar(positive=['zauberer'], topn=10)
# Out:
# [('zauberern', 0.9454124569892883),
#  ('zauberers', 0.9284659624099731),
#  ('zauberer_hexen', 0.9060564637184143),
#  ('hexen_zauberer', 0.9008322954177856),
#  ('zauberer_welt', 0.8971052765846252),
#  ('zaubererwelt', 0.8884369134902954),
#  ('jungen_zauberer', 0.8768090605735779),
#  ('zauberei', 0.8591758608818054),
#  ('hexen_zauberern', 0.8582679033279419),
#  ('zauberwelt', 0.8454762697219849)]

# %%
# Hilfsfunktion zum Plotten ähnlicher Wörter im Vektorraum

def plot_closest_words(model, word, plot_style):
    
    arr = np.empty((0,300), dtype='f') 
    closest_words = model.wv.similar_by_word(word)
    word_labels = [word]
    arr = np.append(arr, np.array([model[word]]), axis=0)
    
    for wrd_score in closest_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
                
    plt.figure(figsize=[12,6])
    plt.style.use(plot_style)
                    
    tsne = TSNE(n_components=2, random_state=42)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
    plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
    plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
plot_closest_words(ft_ff, 'harry', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
plot_closest_words(ft_ff, 'quidditch', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
plot_closest_words(ft_ff, 'schule', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## Verrechnung der Vektoren

# %%
# Hilfsfunktion zur Analogiebildung

def analogy(model, word1, word2, word3):
    similarities = model.wv.most_similar(positive=[word1, word3], negative=[word2])
    word4 = similarities[0][0]
    print('{word1} steht in Beziehung zu {word2}, wie {word4} zu {word3}'.format(**locals()))
    return word4

# %%
analogy(ft_ff, 'gryffindor', 'harry', 'luna')
# Out:
# gryffindor steht in Beziehung zu harry, wie ravenclaw zu luna
# 'ravenclaw'

# %%
analogy(ft_ff, 'narbe', 'harry', 'ron')
# Out:
# narbe steht in Beziehung zu harry, wie haarfarbe zu ron
# 'haarfarbe'

# %%
analogy(ft_ff, 'zauberer', 'mann', 'frau')
# Out:
# zauberer steht in Beziehung zu mann, wie zauberern zu frau
# 'zauberern'
