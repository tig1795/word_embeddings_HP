# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import re
import nltk
import os
from joblib import Parallel, delayed  
from gensim.models import Word2Vec
from gensim.models.phrases import Phraser, Phrases
import codecs
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from tabulate import tabulate

nltk.download('punkt')
tokenizer = nltk.data.load('tokenizers/punkt/german.pickle')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Günther\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
hp = pd.read_csv('../../Datensatz/df_original.csv')
hp.head(2)
# Out:
#    Unnamed: 0         Autor                                       Titel  \
# 0           0  J.K. Rowling  HARRY POTTER und der Gefangene von Askaban
# 1           1  J.K. Rowling          HARRY POTTER und der Halbblutprinz
#
#     Übersetzer                            Original_Titel               ISBN  \
# 0  Klaus Fritz  Harry Potter and the Prisoner of Azkaban  978-1-78110-057-8
# 1  Klaus Fritz    Harry Potter and the Half-Blood Prince  978-1-78110-060-8
#
#    Datum                                               Text  \
# 0   1999  \r\n\r\n\r\nFür Jill Prewett und Aine Kiely,\r...
# 1   2005  \r\n\r\n\r\nMackenzie,\r\n\r\nmeiner schönen T...
#
#                              removed_stop_word_lower  \
# 0  \r\n\r\n\r\nfür jill prewett und aine kiely,\r...
# 1  \r\n\r\n\r\nmackenzie,\r\n\r\nmeiner schönen t...
#
#                                    removed_stop_word  number_of_tokens  \
# 0  jill prewett aine kiely, patinnen souls inhalt...          115980.0
# 1  mackenzie, schönen tochter, widme zwilling tin...          179884.0
#
#    number_of_types                                         clean_text  \
# 0          19479.0  jill prewett aine kiely patinnen souls inhalt ...
# 1          26838.0  mackenzie schönen tochter widme zwilling tinte...
#
#                                         network_text
# 0    für jill prewett und aine kiely  die patinne...
# 1    mackenzie  meiner schönen tochter  widme ich...

# %%
hp.shape
# Out:
# (7, 14)

# %%
# Hilfsfunktion zur Bereinigung und Tokenisierung

def sentence_to_wordlist(raw:str):
    return re.sub('[^A-Za-z_äÄöÖüÜß]',' ', raw).split()

# %%
# Hilfsfunktion zur Extraktion der Sätze
# gibt eine List von tokenisierten Sätzen aus 
# berücksichtigt auch Bigramme

def prepare_text(raw_text):
    raw_sentences = tokenizer.tokenize(str(raw_text))
    tokenized_sentences = Parallel(n_jobs=-1)(delayed(sentence_to_wordlist)(raw_sentence) for raw_sentence in raw_sentences)
    phrases = Phrases(tokenized_sentences)
    bigram = Phraser(phrases)
    sentences = list(bigram[tokenized_sentences])
    return sentences

# %%
text1 = hp.network_text[0] # HP und der Orden des Phönix
text2 = hp.network_text[1]
text3 = hp.network_text[2]
text4 = hp.network_text[3]
text5 = hp.network_text[4]
text6 = hp.network_text[5]
text7 = hp.network_text[6]

books = text1+text2+text3+text4+text5+text6+text7

# %%
#books

# %%
sentences = prepare_text(books)

# sentences ist eine Liste von tokenisierten Sätzen, zum Beispiel:
#print(sentences[100])
# Out:
# INFO - 16:51:15: collecting all words and their counts
# INFO - 16:51:15: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 16:51:18: collected 460693 word types from a corpus of 1137820 words (unigram + bigrams) and 1 sentences
# INFO - 16:51:18: using 460693 counts as vocab in Phrases<0 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>
# INFO - 16:51:18: source_vocab length 460693
# INFO - 16:51:25: Phraser built with 4005 phrasegrams

# %% [markdown]
# # Training von Word2Vec (mit Gensim)

# %%
# Paramter setzen
workers = 4
seed = 42 #just because

# %%
from nltk.corpus import stopwords

stop = stopwords.words('german')

# %%
# Training
w2v_hp1_7 = Word2Vec(sentences=sentences, 
                   size=300, window=7, 
                   min_count=3, workers=workers, 
                   sg=1, seed=seed)

# trainiertes Modell speichern
w2v_hp1_7.save(os.path.join('trained_models', 'hp1_7_w2v.bin'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-244-cafd8367ed51> in <module>
#       4                    stop_words = stopwords.words('german'),
#       5                    min_count=3, workers=workers,
# ----> 6                    sg=1, seed=seed)
#       7
#       8 # trainiertes Modell speichern
#
# TypeError: __init__() got an unexpected keyword argument 'stop_words'

# %%
# trainiertes Modell laden
w2v_hp1_7 = Word2Vec.load(os.path.join('trained_models', 'hp1_7_w2v.bin'))
# Out:
# INFO - 16:51:56: loading Word2Vec object from trained_models\hp1_7_w2v.bin
# INFO - 16:51:57: loading wv recursively from trained_models\hp1_7_w2v.bin.wv.* with mmap=None
# INFO - 16:51:57: setting ignored attribute vectors_norm to None
# INFO - 16:51:57: loading vocabulary recursively from trained_models\hp1_7_w2v.bin.vocabulary.* with mmap=None
# INFO - 16:51:57: loading trainables recursively from trained_models\hp1_7_w2v.bin.trainables.* with mmap=None
# INFO - 16:51:57: setting ignored attribute cum_table to None
# INFO - 16:51:57: loaded trained_models\hp1_7_w2v.bin

# %% [markdown]
# # Exploration des Word2Vec-Modells

# %% [markdown]
# ## Wörter als Vektoren

# %%
# Vergleicht 2 Vektoren (Cosinus Similarität)

w2v_hp1_7.similarity('harry', 'ron')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.99987924

# %%
w2v_hp1_7.similarity('harry', 'besen')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9998039

# %%
# Wortvektoren als DataFrame 

tsne = TSNE(n_components=2, random_state=seed)
word_vectors = w2v_hp1_7.wv.syn0
word_vectors_2d = tsne.fit_transform(word_vectors)

points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, word_vectors_2d[w2v_hp1_7.wv.vocab[word].index])
            for word in w2v_hp1_7.wv.vocab
        ]
    ],
    columns=['word', 'x', 'y'])

# random 5 Wörter und ihre Koordinaten ausgeben
points.sample(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   after removing the cwd from sys.path.
#            word          x          y
# 9297    loderte  -1.454718  -2.005387
# 4573    unseren  -9.868822  -9.400224
# 15208    genaue   5.317252 -21.353214
# 10950  weswegen  -1.024329  23.887938
# 16938   geprägt -29.121044  28.468792

# %%
# alle Wortvektoren plotten

sns.set_context('poster')

plt.style.use('seaborn-whitegrid')
points.plot.scatter('x', 'y', s=10, figsize=(20, 12))

# %%
# Hilfsfunktion, um durch den Plot zu navigieren (ranzoomen)

def plot_region(x_bounds, y_bounds, padding=0.005, fontsize=11):
    myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]
    
    ax = myslice.plot.scatter('x', 'y', s=35, figsize=(9, 5))
    for i, point in myslice.iterrows():
        ax.text(point.x + padding, point.y + padding, point.word, fontsize=fontsize)

# %%
# ranzoomen
x_bounds = (15, 20)       # Bereich x-Achse einstellen
y_bounds = (30, 35)       # Bereich y-Achse einstellen

myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]

len(myslice)

plot_region(x_bounds=x_bounds, y_bounds=y_bounds)

# %%
# nur ausgewählte Wortvektoren plotten

tsne = TSNE(n_components=2, random_state=seed)

words =  ['harry', 'potter', 'ron', 'hermine', 'ginny', 'dean', 'neville', 'cho', 'fred', 'george', 
          'mr_weasley', 'mrs_weasley', 'cedric', 'voldemort', 'bellatrix', 'malfoy', 'draco', 'lucius', 'sirius', 
          'james', 'lupin', 'wurmschwanz', 'lily', 'dobby', 'elf', 'zauberer', 'hexe', 'hogwarts',
          'gryffindor', 'slytherin', 'ravenclaw', 'hufflepuff',
          'sprout', 'flitwick', 'hagrid', 'dumbledore', 'snape', 'umbridge', 'minister', 'ministerium',
          'little_whinging', 'london', 'dursley', 'gringotts',
          'quidditch', 'besen', 'feuerblitz', 'schnatz', 'sucher', 'treiber', 'bibliothek', 'buch', 'geist',
          'eule', 'katze', 'hedwig', 'hund', 'patronus', 'tier', 'animagus', 'umhang', 'zauberstab', 'zaubertrank']

vectors = [w2v_hp5[word] for word in words]
plt.figure(figsize=[30,25])
plt.style.use('seaborn-whitegrid')
Y = tsne.fit_transform(vectors[:200])
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ## Ähnliche Wörer

# %%
w2v_hp1_7.most_similar(positive=['harry'], topn=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# INFO - 17:12:03: precomputing L2-norms of word weight vectors
# [('der', 0.9999235272407532),
#  ('die', 0.9999212026596069),
#  ('in', 0.9999203085899353),
#  ('den', 0.9999165534973145),
#  ('auf', 0.9999161958694458)]

# %%
w2v_hp1_7.most_similar(positive=['quidditch'], topn=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('haben', 0.9997446537017822),
#  ('des', 0.9997413754463196),
#  ('alle', 0.9997386336326599),
#  ('gerade', 0.9997382164001465),
#  ('ern', 0.9997364282608032)]

# %%
w2v_hp1_7.most_similar(positive=['hexe'], topn=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('als', 0.9998108148574829),
#  ('einen', 0.9997953772544861),
#  ('für', 0.9997951984405518),
#  ('bett', 0.9997944831848145),
#  ('hat', 0.9997926354408264)]

# %%
# Hilfsfunktion zum Plotten ähnlicher Wörter im Vektorraum

def plot_closest_words(model, word, plot_style):
    
    arr = np.empty((0,300), dtype='f') 
    closest_words = model.similar_by_word(word)
    word_labels = [word]
    arr = np.append(arr, np.array([model[word]]), axis=0)
    
    for wrd_score in closest_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
                
    plt.figure(figsize=[12,6])
    plt.style.use(plot_style)
                    
    tsne = TSNE(n_components=2, random_state=42)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
    plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
    plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
plot_closest_words(w2v_hp5, 'harry', 'seaborn-whitegrid')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#
# INFO - 17:13:48: precomputing L2-norms of word weight vectors
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
plot_closest_words(w2v_hp5, 'hogwarts', 'seaborn-whitegrid')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## Verrechnung der Vektoren

# %%
# Hilfsfunktion zur Analogiebildung

def analogy(model, word1, word2, word3):
    similarities = model.most_similar(positive=[word1, word3], negative=[word2])
    word4 = similarities[0][0]
    print('{word1} steht in Beziehung zu {word2}, wie {word4} zu {word3}'.format(**locals()))
    return word4

# %%
analogy(w2v_hp1_7, 'harry', 'zauberer', 'hexe')
# Out:
# harry steht in Beziehung zu zauberer, wie auf zu hexe
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   after removing the cwd from sys.path.
# 'auf'
