# %% [markdown]
# <h1>Word2Vec</h1>

# %% [markdown]
# <h3>Vorbereitung</h3>

# %%
import pandas as pd
import numpy as np
import re
import nltk
import os
from joblib import Parallel, delayed  
from gensim.models import Word2Vec
from gensim.models.phrases import Phraser, Phrases
import codecs
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from tabulate import tabulate

nltk.download('punkt')
tokenizer = nltk.data.load('tokenizers/punkt/german.pickle')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Elke\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
hp = pd.read_csv('data/df_original.csv', encoding='utf-8')
hp.head()
# Out:
#    Unnamed: 0         Autor                                       Titel  \
# 0           0  J.K. Rowling  HARRY POTTER und der Gefangene von Askaban
# 1           1  J.K. Rowling          HARRY POTTER und der Halbblutprinz
# 2           2  J.K. Rowling       HARRY POTTER und der Orden des Phönix
# 3           3  J.K. Rowling       HARRY POTTER und der Stein der Weisen
# 4           4  J.K. Rowling  HARRY POTTER und die Heiligtümer des Todes
#
#     Übersetzer                             Original_Titel               ISBN  \
# 0  Klaus Fritz   Harry Potter and the Prisoner of Azkaban  978-1-78110-057-8
# 1  Klaus Fritz     Harry Potter and the Half-Blood Prince  978-1-78110-060-8
# 2  Klaus Fritz  Harry Potter and the Order of the Phoenix  978-1-78110-059-2
# 3  Klaus Fritz   Harry Potter and the Philosopher’s Stone  978-1-78110-055-4
# 4  Klaus Fritz       Harry Potter and the Deathly Hallows  978-1-78110-061-5
#
#    Datum                                               Text  \
# 0   1999  \n\n\nFür Jill Prewett und Aine Kiely,\n\ndie ...
# 1   2005  \n\n\nMackenzie,\n\nmeiner schönen Tochter,\n\...
# 2   2003  \n\n\n\n\nFür Neil, Jessica und David,\n\ndie ...
# 3   1997  \n\n\n\nFür Jessica, für Anne und fü Di;\n\nJe...
# 4   2007  \n\n\nDie\n\nWidmung\n\ndieses Buches\n\nist\n...
#
#                              removed_stop_word_lower  \
# 0  \n\n\nfür jill prewett und aine kiely,\n\ndie ...
# 1  \n\n\nmackenzie,\n\nmeiner schönen tochter,\n\...
# 2  \n\n\n\n\nfür neil, jessica und david,\n\ndie ...
# 3  \n\n\n\nfür jessica, für anne und fü di;\n\nje...
# 4  \n\n\ndie\n\nwidmung\n\ndieses buches\n\nist\n...
#
#                                    removed_stop_word  number_of_tokens  \
# 0  jill prewett aine kiely, patinnen souls inhalt...          115980.0
# 1  mackenzie, schönen tochter, widme zwilling tin...          179884.0
# 2  neil, jessica david, welt verzaubern inhalt du...          268898.0
# 3  jessica, anne fü di; jessica mag geschichten, ...           84152.0
# 4  widmung buches siebengeteilt: neil, jessica, d...          207576.0
#
#    number_of_types                                         clean_text  \
# 0          19479.0  jill prewett aine kiely patinnen souls inhalt ...
# 1          26838.0  mackenzie schönen tochter widme zwilling tinte...
# 2          35356.0  neil jessica david welt verzaubern inhalt dudl...
# 3          15910.0  jessica anne fü di jessica mag geschichten ann...
# 4          29725.0  widmung buches siebengeteilt neil jessica davi...
#
#                                         network_text
# 0    für jill prewett und aine kiely  die patinne...
# 1    mackenzie  meiner schönen tochter  widme ich...
# 2     für neil jessica und david  die meine welt ...
# 3    für jessica für anne und fü di  jessica mag ...
# 4    die  widmung  dieses buches  ist  siebengete...

# %%
# Hilfsfunktion zur Bereinigung und Tokenisierung

def sentence_to_wordlist(raw:str):
    return re.sub('[^a-zA-Z]',' ', raw).split()

# %%
# Hilfsfunktion zur Extraktion der Sätze
# gibt eine List von tokenisierten Sätzen aus 
# berücksichtigt auch Bigramme

def prepare_text(raw_text):
    raw_sentences = tokenizer.tokenize(raw_text.lower())
    tokenized_sentences = Parallel(n_jobs=-1)(delayed(sentence_to_wordlist)(raw_sentence) for raw_sentence in raw_sentences)
    phrases = Phrases(tokenized_sentences)
    bigram = Phraser(phrases)
    sentences = list(bigram[tokenized_sentences])
    return sentences

# %%
text = hp.Text[2] # HP und der Orden des Phönix

sentences = prepare_text(text)

# sentences ist eine Liste von tokenisierten Sätzen, zum Beispiel:
print(sentences[1000])
# Out:
# ['zitternd', 'blickte', 'harry', 'sich', 'um']

# %% [markdown]
# <h3>Training von Word2Vec (mit Gensim)</h3>

# %%
# Paramter setzen
workers = 4
seed = 42 #just because

# %%
# Ordner anlegen zum Abspeichern von trainierten Modellen
if not os.path.exists('trained_models'):
    os.makedirs('trained_models')

# %%
# Training
w2v_hp5 = Word2Vec(sentences=sentences, 
                   size=300, window=7, 
                   min_count=3, workers=workers, 
                   sg=1, seed=seed)

# trainiertes Modell speichern
w2v_hp5.save(os.path.join('trained_models', 'hp5_w2v.bin'))

# %%
# trainiertes Modell laden
w2v_hp5 = Word2Vec.load(os.path.join('trained_models', 'hp5_w2v.bin'))

# %% [markdown]
# <h3>Exploration des Word2Vec-Modells</h3>

# %% [markdown]
# <h4>Wörter als Vektoren</h4>

# %%
# Vergleicht 2 Vektoren (Cosinus Similarität)

w2v_hp5.similarity('harry', 'ron')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.7369419

# %%
w2v_hp5.similarity('harry', 'besen')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.62964696

# %%
# Wortvektoren als DataFrame 

tsne = TSNE(n_components=2, random_state=seed)
word_vectors = w2v_hp5.wv.syn0
word_vectors_2d = tsne.fit_transform(word_vectors)

points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, word_vectors_2d[w2v_hp5.wv.vocab[word].index])
            for word in w2v_hp5.wv.vocab
        ]
    ],
    columns=['word', 'x', 'y'])

# random 5 Wörter und ihre Koordinaten ausgeben
points.sample(5)
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   after removing the cwd from sys.path.
#            word          x          y
# 2032      wohin -63.028347  -2.643909
# 4970      anzuh -56.997494  31.665272
# 4337      terin  29.634998  56.027782
# 2057  entrollte  64.823914  -4.993680
# 5043     berein   5.343944  51.321598

# %%
# alle Wortvektoren plotten

sns.set_context('poster')

plt.style.use('seaborn-whitegrid')
points.plot.scatter('x', 'y', s=10, figsize=(20, 12))

# %%
# Hilfsfunktion, um durch den Plot zu navigieren (ranzoomen)

def plot_region(x_bounds, y_bounds, padding=0.005, fontsize=11):
    myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]
    
    ax = myslice.plot.scatter('x', 'y', s=35, figsize=(9, 5))
    for i, point in myslice.iterrows():
        ax.text(point.x + padding, point.y + padding, point.word, fontsize=fontsize)

# %%
# ranzoomen
x_bounds = (15, 20)       # Bereich x-Achse einstellen
y_bounds = (30, 35)       # Bereich y-Achse einstellen

myslice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])]

len(myslice)

plot_region(x_bounds=x_bounds, y_bounds=y_bounds)

# %%
# nur ausgewählte Wortvektoren plotten

tsne = TSNE(n_components=2, random_state=seed)

words =  ['harry', 'potter', 'ron', 'hermine', 'ginny', 'dean', 'neville', 'cho', 'fred', 'george', 
          'mr_weasley', 'mrs_weasley', 'cedric', 'voldemort', 'bellatrix', 'malfoy', 'draco', 'lucius', 'sirius', 
          'james', 'lupin', 'wurmschwanz', 'lily', 'dobby', 'elf', 'zauberer', 'hexe', 'hogwarts',
          'gryffindor', 'slytherin', 'ravenclaw', 'hufflepuff',
          'sprout', 'flitwick', 'hagrid', 'dumbledore', 'snape', 'umbridge', 'minister', 'ministerium',
          'little_whinging', 'london', 'dursley', 'gringotts',
          'quidditch', 'besen', 'feuerblitz', 'schnatz', 'sucher', 'treiber', 'bibliothek', 'buch', 'geist',
          'eule', 'katze', 'hedwig', 'hund', 'patronus', 'tier', 'animagus', 'umhang', 'zauberstab', 'zaubertrank']

vectors = [w2v_hp5[word] for word in words]
plt.figure(figsize=[30,25])
plt.style.use('seaborn-whitegrid')
Y = tsne.fit_transform(vectors[:200])
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
plt.show()
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# <h4>Ähnliche Wörter</h4>

# %%
w2v_hp5.most_similar(positive=['harry'], topn=5)
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('mrs_weasley', 0.9173942804336548),
#  ('neville', 0.9021651744842529),
#  ('malfoy', 0.894662618637085),
#  ('umbridge', 0.8701205849647522),
#  ('snape', 0.8671044111251831)]

# %%
w2v_hp5.most_similar(positive=['quidditch'], topn=5)
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('wochenende', 0.9790645837783813),
#  ('land', 0.9779596924781799),
#  ('ausgerechnet', 0.9769131541252136),
#  ('au_ergew', 0.976483941078186),
#  ('amt', 0.975881814956665)]

# %%
w2v_hp5.most_similar(positive=['hexe'], topn=5)
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('kurzen', 0.9769745469093323),
#  ('fl_ssigkeit', 0.9683578610420227),
#  ('der_mitte', 0.9677587747573853),
#  ('schwarzem', 0.9654356241226196),
#  ('tiefen', 0.9639736413955688)]

# %%
# Hilfsfunktion zum Plotten ähnlicher Wörter im Vektorraum

def plot_closest_words(model, word, plot_style):
    
    arr = np.empty((0,300), dtype='f') 
    closest_words = model.similar_by_word(word)
    word_labels = [word]
    arr = np.append(arr, np.array([model[word]]), axis=0)
    
    for wrd_score in closest_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
                
    plt.figure(figsize=[12,6])
    plt.style.use(plot_style)
                    
    tsne = TSNE(n_components=2, random_state=42)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
    plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
    plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
plot_closest_words(w2v_hp5, 'harry', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
plot_closest_words(w2v_hp5, 'hogwarts', 'seaborn-whitegrid')
# Out:
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# <h3>Verrechnung der Vektoren</h3>

# %%
# Hilfsfunktion zur Analogiebildung

def analogy(model, word1, word2, word3):
    similarities = model.most_similar(positive=[word1, word3], negative=[word2])
    word4 = similarities[0][0]
    print('{word1} steht in Beziehung zu {word2}, wie {word4} zu {word3}'.format(**locals()))
    return word4

# %%
analogy(w2v_hp5, 'harry', 'zauberer', 'hexe')
# Out:
# harry steht in Beziehung zu zauberer, wie neville zu hexe
# C:\Users\Elke\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   after removing the cwd from sys.path.
# 'neville'

# %%
# also das funktioniert noch nicht so ganz...
# Wahrscheinlich ist es besser, Word2Vec auf alle 7 Bücher auf auf einmal zu trainieren, da ein einziger Text zu kurz ist!
